# %% [markdown]
# <a href="https://colab.research.google.com/github/Non8q/IT326-Social-Media-Addiction-and-Usage-Patterns/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("Raw_dataset.csv")

# %%
# 1. Dataset Description
print("-- Dataset General Information --")
print(f"Number of objects (instances): {df.shape[0]}")
print(f"Number of attributes (features): {df.shape[1]}")

print("\n-- Data Types of Attributes --")
print(df.dtypes)
# Out:
# -- Dataset General Information --
# Number of objects (instances): 20
# Number of attributes (features): 15
#
# -- Data Types of Attributes --
# User_ID                        int64
# Age                            int64
# Gender                        object
# Platform                      object
# Daily_Usage_Time_min           int64
# Posts_Per_Day                  int64
# Likes_Received_Daily           int64
# Comments_Received_Daily        int64
# Messages_Sent_Daily            int64
# Scroll_Rate_ppm                int64
# Addiction_Level               object
# Emotional_State_Post_Usage    object
# Productivity_Loss_Score        int64
# Mental_Health_Index            int64
# FOMO_Score                     int64
# dtype: object

# %%
print("\n--Class Attribute Distribution (Addiction_Level) --")
print(df['Addiction_Level'].value_counts())
# Out:
# --Class Attribute Distribution (Addiction_Level) --
# Addiction_Level
# High        6
# Moderate    6
# Low         5
# Severe      3
# Name: count, dtype: int64

# %%
print("\n-- Sample of the Raw Dataset --")
df.head()
# Out:
# -- Sample of the Raw Dataset --
#    User_ID  Age      Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 0     1001   23      Female  Instagram                   145              3
# 1     1002   19        Male     TikTok                   210              1
# 2     1003   28      Female   LinkedIn                    45              0
# 3     1004   35        Male   Facebook                    90              2
# 4     1005   21  Non-binary    Twitter                   180             15
#
#    Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 0                   120                       25                   45
# 1                    45                        5                   10
# 2                     5                        2                   15
# 3                    30                       10                   20
# 4                   200                       60                   50
#
# ...
